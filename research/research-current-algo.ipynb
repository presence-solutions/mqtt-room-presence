# %% [markdown]
# # Задача
# На данный момент имеется алгоритм, который работает вполне сносно, с переодическими ошибками. Задача изучить метрики качества этого алгоритма, чтоб иметь бэйзлайн, который следует улучшить.
